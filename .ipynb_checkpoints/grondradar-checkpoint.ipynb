# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
df = pd.read_excel(r"C:\Users\Iris Reitsma\Documents\Master\jaar 2\stage\validatie\Grondradar\pixelcount.xlsx")
display(df)
# Out:
#     Boomnummer  number of points  width_m  height_m  width_pixel  \
# 0            1            219579        8         8          495
# 1            2            204774        8         8          495
# 2            3            324149        6         6          495
# 3            4            193887        8         8          495
# 4            5            273189        6        12          339
# 5            6            402902        6        10          353
# 6           10            597489        5         8          449
# 7           11            412944        5        11          305
# 8           12            350132        7        13          365
# 9           13            155864        8         8          495
# 10          14            135403        8        10          471
# 11          15            380818        4         4          495
# 12          16            363941        5         5          495
# 13          17            312602        5         5          485
# 14          18            186580        8         8          495
# 15          19            170158        6         6          495
# 16          20            227630        4         4          495
# 17          21            203358        8         8          495
# 18          22            140848        8         8          500
#
#     height_pixel   shape
# 0            495  circle
# 1            495  circle
# 2            495  circle
# 3            495  circle
# 4            678    line
# 5            586    line
# 6            714    line
# 7            672    line
# 8            686    line
# 9            495    line
# 10           590    line
# 11           495  circle
# 12           495  circle
# 13           485  circle
# 14           495  circle
# 15           495  circle
# 16           495  circle
# 17           495  circle
# 18           500  circle

# %%
df['area_m'] = df['width_m'] * df['height_m']
df['area_pixel'] = df['width_pixel'] * df['height_pixel']
df['normalized'] = df['number of points'] / df['area_pixel'] * df['area_m']
normalized = np.array(df['normalized'])
boomnummer = np.array(df['Boomnummer'])
df['color'] = 'C0'
df['color'][df['shape'] == 'line'] = 'C1'
display(df)
# Out:
# <ipython-input-3-3903caf0b319>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['color'][df['shape'] == 'line'] = 'C1'
#     Boomnummer  number of points  width_m  height_m  width_pixel  \
# 0            1            219579        8         8          495
# 1            2            204774        8         8          495
# 2            3            324149        6         6          495
# 3            4            193887        8         8          495
# 4            5            273189        6        12          339
# 5            6            402902        6        10          353
# 6           10            597489        5         8          449
# 7           11            412944        5        11          305
# 8           12            350132        7        13          365
# 9           13            155864        8         8          495
# 10          14            135403        8        10          471
# 11          15            380818        4         4          495
# 12          16            363941        5         5          495
# 13          17            312602        5         5          485
# 14          18            186580        8         8          495
# 15          19            170158        6         6          495
# 16          20            227630        4         4          495
# 17          21            203358        8         8          495
# 18          22            140848        8         8          500
#
#     height_pixel   shape  area_m  area_pixel  normalized color
# 0            495  circle      64      245025   57.353560    C0
# 1            495  circle      64      245025   53.486526    C0
# 2            495  circle      36      245025   47.625197    C0
# 3            495  circle      64      245025   50.642865    C0
# 4            678    line      72      229842   85.578824    C1
# 5            586    line      60      206858  116.863356    C1
# 6            714    line      40      320586   74.549606    C1
# 7            672    line      55      204960  110.811475    C1
# 8            686    line      91      250390  127.249539    C1
# 9            495    line      64      245025   40.711340    C1
# 10           590    line      80      277890   38.980316    C1
# 11           495  circle      16      245025   24.867209    C0
# 12           495  circle      25      245025   37.133048    C0
# 13           485  circle      25      235225   33.223722    C0
# 14           495  circle      64      245025   48.734292    C0
# 15           495  circle      36      245025   25.000257    C0
# 16           495  circle      16      245025   14.864116    C0
# 17           495  circle      64      245025   53.116670    C0
# 18           500  circle      64      250000   36.057088    C0

# %%
volume_centraal_static = np.load(r"C:\Users\Iris Reitsma\Documents\Master\jaar 2\stage\root_model\output\numpy_files\Centraal_static_volume.npy")[0]
volume_centraal_treedict = np.load(r"C:\Users\Iris Reitsma\Documents\Master\jaar 2\stage\root_model\output\numpy_files\Centraal_treedict_volume.npy")[0]
volume_centraal_treegrowth = np.load(r"C:\Users\Iris Reitsma\Documents\Master\jaar 2\stage\root_model\output\numpy_files\Centraal_treegrowth_volume.npy")[0]
marginal_static = volume_centraal_static.T[0]
df['static'] = marginal_static
marginal_treedict = volume_centraal_treedict.T[0]
df['treedict'] = marginal_treedict
marginal_treegrowth = volume_centraal_treegrowth.T[0]
df['treegrowth'] = marginal_treegrowth

# %%
def plot(df, model):
#     df.sort_values(by=model)
    plt.scatter(df[model], df['normalized'], color=df['color'])
        
    legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor='C0', label='circular scan'),
                    Line2D([0], [0], marker='o', color='w', markerfacecolor='C1', label='linear scan'),
                    ]
    
    for i, txt in df.iterrows():
        plt.annotate(txt['Boomnummer'], (txt[model], txt['normalized']+3), fontsize=12)
    
    plt.xlabel('Estimated volume ($m^3$)', fontsize=14)
    plt.ylabel('Voxel count', fontsize=14)
    plt.legend(handles=legend_elements)
    plt.tight_layout()
    plt.ylim(10,140)
    plt.savefig('plots/groundradar_{}'.format(model), dpi=300)
    plt.show()

# %%
plot(df, 'static')
plot(df, 'treedict')
plot(df, 'treegrowth')

# %%
marginal_treedict = volume_centraal_treedict.T[0]
print(marginal_static)

zipped_lists = zip(marginal_treedict, normalized)
sorted_zipped_lists = sorted(zipped_lists)
sorted_normalized = [element for _, element in sorted_zipped_lists]


zipped_lists = zip(marginal_treedict, boomnummer)
sorted_zipped_lists = sorted(zipped_lists)
sorted_boomnummer = [element for _, element in sorted_zipped_lists]
plt.scatter(np.sort(marginal_treedict), sorted_normalized)
# Out:
# [24.3        18.2        13.8        16.         30.5        33.9
#   8.8        27.13333333 56.53333333  8.10666667 65.96666667  3.77333333
#   4.12        4.405      27.         18.2         5.27       13.13333333
#  27.        ]

# %%
marginal_treegrowth = volume_centraal_treegrowth.T[0]
print(marginal_static)

zipped_lists = zip(marginal_treegrowth, normalized)
sorted_zipped_lists = sorted(zipped_lists)
sorted_normalized = [element for _, element in sorted_zipped_lists]


zipped_lists = zip(marginal_treegrowth, boomnummer)
sorted_zipped_lists = sorted(zipped_lists)
sorted_boomnummer = [element for _, element in sorted_zipped_lists]
plt.scatter(np.sort(marginal_treegrowth), sorted_normalized)
# Out:
# [24.3        18.2        13.8        16.         30.5        33.9
#   8.8        27.13333333 56.53333333  8.10666667 65.96666667  3.77333333
#   4.12        4.405      27.         18.2         5.27       13.13333333
#  27.        ]

# %%
list1 = ['a', 'b', 'c']
list2 = [2, 3, 1]
zipped_lists = zip(list2, list1) #Pair list2 and list1 elements.
sorted_zipped_lists = sorted(zipped_lists) #Sort by first element of each pair.
sorted_list1 = [element for _, element in sorted_zipped_lists]
print(sorted_list1)
# Out:
# ['c', 'a', 'b']
